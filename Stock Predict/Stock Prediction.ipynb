# %%
import pandas as pd 
import numpy as np 
from datetime import datetime as dt

# %%
df = pd.read_csv("AAPL.csv")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-08-02   37.205715   37.512856   37.088570   37.407143   25.225733
# 1     2010-08-03   37.287144   37.608570   37.060001   37.418571   25.233450
# 2     2010-08-04   37.548573   37.754284   37.187141   37.568573   25.334602
# 3     2010-08-05   37.389999   37.597141   37.221428   37.385715   25.211288
# 4     2010-08-06   37.111427   37.355713   36.804287   37.155716   25.056183
# 5     2010-08-09   37.354286   37.450001   37.081429   37.392857   25.216099
# 6     2010-08-10   37.121429   37.207142   36.792858   37.058571   24.990675
# 7     2010-08-11   36.485714   36.527142   35.687141   35.741428   24.102459
# 8     2010-08-12   35.241428   36.157143   35.160000   35.970001   24.256594
# 9     2010-08-13   35.950001   35.982857   35.584286   35.585712   23.997446
# 10    2010-08-16   35.368572   35.715714   35.231430   35.377144   23.856789
# ...

# %%
# %matplotlib inline
df.plot('Date','Close')

# %%
# %matplotlib inline
df.plot('Date','Volume')
